# %%
import pandas as pd

# %%
df=pd.read_csv("data/data.csv")

# %%
df
# Out:
#                         airportname aircraftmodel amountofdamage Flight Date  \
# 0     BARKSDALE AIR FORCE BASE ARPT         T-38A           None  01/08/1990
# 1     BARKSDALE AIR FORCE BASE ARPT        KC-10A           None  01/09/1990
# 2     BARKSDALE AIR FORCE BASE ARPT          B-52           None  01/11/1990
# 3                  NEW ORLEANS INTL     B-737-300    Substantial  01/11/1990
# 4     BARKSDALE AIR FORCE BASE ARPT        KC-10A           None  01/12/1990
# ...                             ...           ...            ...         ...
# 9995                   LAGUARDIA NY         A-319           None   7/24/2002
# 9996    DALLAS/FORT WORTH INTL ARPT         MD-83           None   7/24/2002
# 9997            DENVER INTL AIRPORT         MD-82           None   7/24/2002
# 9998  BARKSDALE AIR FORCE BASE ARPT         B-52H           None   7/25/2002
# 9999             GREATER PITTSBURGH       EMB-145           None   7/25/2002
#
#      Aircraft Airline Operator  Origin State Phase of flight Wildlife Size  \
# 0                     MILITARY     Louisiana           Climb         Large
# 1                     MILITARY     Louisiana        Approach        Medium
# 2                     MILITARY     Louisiana    Take-off run        Medium
# 3           SOUTHWEST AIRLINES     Louisiana    Take-off run         Small
# 4                     MILITARY     Louisiana           Climb        Medium
# ...                        ...           ...             ...           ...
# 9995               US AIRWAYS*      New York           Climb         Small
# 9996         AMERICAN AIRLINES         Texas         Descent         Small
# 9997         AMERICAN AIRLINES      Colorado    Take-off run         Small
# 9998                  MILITARY     Louisiana           Climb        Medium
# 9999     TRANS STATES AIRLINES  Pennsylvania           Climb        Medium
#
#           Wildlife Species Time of day  Cost Other  Cost Repair  Cost Total $  \
# 0           Turkey vulture         Day           0            0             0
# 1      Unknown bird or bat       Night           0            0             0
# 2      Unknown bird or bat         Day           0            0             0
# 3              Rock pigeon         Day           0            0             0
# 4      Unknown bird or bat         Day           0            0             0
# ...                    ...         ...         ...          ...           ...
# 9995     European starling         Day           0            0             0
# 9996  Unknown bird - small         Day           0            0             0
# 9997           Horned lark         Day           0            0             0
# 9998   Unknown bird or bat         Day           0            0             0
# 9999       Red-tailed hawk         Day           0            0             0
#
#       Speed IAS in knots  latitude  longitude
# 0                  300.0   32.5019   -93.6571
# 1                  200.0   32.5019   -93.6571
# 2                  130.0   32.5019   -93.6571
# 3                  140.0   29.9911   -90.2592
# 4                  160.0   32.5019   -93.6571
# ...                  ...       ...        ...
# 9995                 NaN   40.7769   -73.8740
# 9996               250.0   32.8998   -97.0403
# 9997               120.0   39.8493  -104.6738
# 9998               110.0   32.5019   -93.6571
# 9999               140.0   40.3565   -79.9193
#
# [10000 rows x 16 columns]

# %%
pd.Series(df["airportname"].unique()).to_csv("planes.csv")

# %%
df.groupby("Origin State").count().to_csv("stateCounts.csv")

# %%
import csv
from collections import defaultdict


def ctree():
    """ One of the python gems. Making possible to have dynamic tree structure.

    """
    return defaultdict(ctree)


def build_leaf(name, leaf):
    """ Recursive function to build desired custom tree structure

    """
    res = {"name": name}

    # add children node if the leaf actually has any children
    if len(leaf.keys()) > 0:
        res["children"] = [build_leaf(k, v) for k, v in leaf.items()]

    return res


def main():
    """ The main thread composed from two parts.

    First it's parsing the csv file and builds a tree hierarchy from it.
    Second it's recursively iterating over the tree and building custom
    json-like structure (via dict).

    And the last part is just printing the result.

    """
    tree = ctree()
    # NOTE: you need to have test.csv file as neighbor to this file
    with open('data/plane.csv') as csvfile:
        reader = csv.reader(csvfile)
        for rid, row in enumerate(reader):

            # skipping first header row. remove this logic if your csv is
            # headerless
            if rid == 0:
                continue

            # usage of python magic to construct dynamic tree structure and
            # basically grouping csv values under their parents
            leaf = tree[row[0]]
            for cid in range(1, len(row)):
                leaf = leaf[row[cid]]

    # building a custom tree structure
    res = []
    for name, leaf in tree.items():
        res.append(build_leaf(name, leaf))

    # printing results into the terminal
    import json
    with open("sample.json", "w") as outfile:
        outfile.write(json.dumps(res))
    print(json.dumps(res))


# so let's roll
main()
# Out:
# [{"name": "ATLANTA INTL", "children": [{"name": "A-319"}, {"name": "A-320"}, {"name": "ATR-72"}, {"name": "B-717-200"}, {"name": "B-727"}, {"name": "B-727-100"}, {"name": "B-727-200"}, {"name": "B-737"}, {"name": "B-737-200"}, {"name": "B-737-300"}, {"name": "B-737-500"}, {"name": "B-757-200"}, {"name": "B-767"}, {"name": "B-767-200"}, {"name": "B-767-300"}, {"name": "B-767-400"}, {"name": "BA-31 JETSTR"}, {"name": "C-130H"}, {"name": "CL-RJ100/200"}, {"name": "DC-10"}, {"name": "DC-8-61"}, {"name": "DC-8-63"}, {"name": "DC-8-70"}, {"name": "DC-9"}, {"name": "DC-9-30"}, {"name": "EMB-120"}, {"name": "FOKKER F100"}, {"name": "HUGHES 500"}, {"name": "L-1011"}, {"name": "LEARJET-25"}, {"name": "MD-80"}, {"name": "MD-82"}, {"name": "MD-83"}, {"name": "MD-88"}, {"name": "MU2"}]}, {"name": "ATLANTIC CITY INTL", "children": [{"name": "ATR-42"}, {"name": "B-727"}, {"name": "B-737"}, {"name": "B-737-200"}, {"name": "BE-100 KING"}, {"name": "BE-1900"}, {"name": "BELL-212"}, {"name": "C-130"}, {"name": "C-130E"}, {"name": "C-130H"}, {"name": "C-135"}, {"name": "C-137C"}, {"name": "C-141"}, {"name": "C-21A"}, {"name": "CASA C-212"}, {"name": "CV-580"}, {"name": "DC-9"}, {"name": "DC-9-30"}, {"name": "DC-9-40"}, {"name": "EC-130E"}, {"name": "EMB-120"}, {"name": "F-16"}, {"name": "F-16A"}, {"name": "F-16C"}, {"name": "FOKKER F100"}, {"name": "GULFAERO III"}, {"name": "HAWKER-SDLY HS125"}, {"name": "KC-10A"}, {"name": "KC-135E"}, {"name": "LEARJET-25"}, {"name": "LEARJET-35"}, {"name": "LEARJET-55"}, {"name": "LOCKHEED 1329"}, {"name": "PA-28"}, {"name": "PA-31 NAVAJO"}, {"name": "SA227 AC METRO III"}, {"name": "SAAB-340"}, {"name": "SHORTS 360"}]}, {"name": "AUSTIN-BERGSTROM INTL", "children": [{"name": "B-717-200"}, {"name": "B-727"}, {"name": "B-727-100"}, {"name": "B-727-200"}, {"name": "B-737"}, {"name": "B-737-200"}, {"name": "B-737-300"}, {"name": "B-737-400"}, {"name": "B-737-500"}, {"name": "B-757-200"}, {"name": "BE-200 KING"}, {"name": "BE-58  BARON"}, {"name": "C-402"}, {"name": "C-425"}, {"name": "CL-RJ100/200"}, {"name": "DC-10-10"}, {"name": "DC-10-30"}, {"name": "DC-8"}, {"name": "DC-8-61"}, {"name": "DC-8-62"}, {"name": "DC-8-63"}, {"name": "DC-9"}, {"name": "DC-9-30"}, {"name": "DC-9-40"}, {"name": "FOKKER F100"}, {"name": "MD-80"}, {"name": "MD-82"}, {"name": "MD-83"}, {"name": "MD-88"}, {"name": "MD-90-30"}]}, {"name": "BALTIMORE WASH INTL", "children": [{"name": "A-319"}, {"name": "A-320"}, {"name": "AEROS SA365"}, {"name": "ATR-42"}, {"name": "B-717-200"}, {"name": "B-727"}, {"name": "B-727-100"}, {"name": "B-727-200"}, {"name": "B-737"}, {"name": "B-737-200"}, {"name": "B-737-300"}, {"name": "B-737-400"}, {"name": "B-737-500"}, {"name": "B-737-700"}, {"name": "B-737-800"}, {"name": "B-757-200"}, {"name": "B-767"}, {"name": "BA-31 JETSTR"}, {"name": "BA-41 JETSTR"}, {"name": "BE-200 KING"}, {"name": "BE-90  KING"}, {"name": "BELLANCA 260"}, {"name": "C-152"}, {"name": "C-208"}, {"name": "C-210 CENTUR"}, {"name": "C-421"}, {"name": "CL-RJ100/200"}, {"name": "DC-10-10"}, {"name": "DC-9"}, {"name": "DC-9-30"}, {"name": "DHC8 DASH 8"}, {"name": "EMB-135"}, {"name": "FOKKER F100"}, {"name": "FOKKER F28 MK 1000"}, {"name": "FOKKER F28 MK 4000"}, {"name": "MD-80"}, {"name": "MD-82"}, {"name": "MD-83"}, {"name": "MD-88"}, {"name": "PA-32"}, {"name": "SAAB-340"}, {"name": "SHORTS 360"}]}, {"name": "BARKSDALE AIR FORCE BASE ARPT", "children": [{"name": "A-10A"}, {"name": "B-1B"}, {"name": "B-52"}, {"name": "B-52G"}, {"name": "B-52H"}, {"name": "C-130E"}, {"name": "E-4B"}, {"name": "F-15C"}, {"name": "KC-10A"}, {"name": "KC-135"}, {"name": "KC-135R"}, {"name": "MC-130P"}, {"name": "SA226 TC"}, {"name": "T-1A"}, {"name": "T-37B"}, {"name": "T-38A"}, {"name": "T-43A"}, {"name": "TC-18F"}]}, {"name": "CHARLESTON AFB/INTL ARPT", "children": [{"name": "A-319"}, {"name": "B-727"}, {"name": "B-737"}, {"name": "B-737-200"}, {"name": "B-737-300"}, {"name": "B-737-400"}, {"name": "B-757-200"}, {"name": "BE-1900"}, {"name": "BE-200 KING"},  ...

# %%
import csv
with open("plane.csv") as f:
    reader = csv.DictReader(f)
    result = [{
        "name": r["parent"],
        "children" : {
            "name": r["node"],
            "count": r["count"],
        }
    } for r in reader]

# %%
import json
with open("sample.json", "w") as outfile:
    outfile.write(json.dumps(result))
